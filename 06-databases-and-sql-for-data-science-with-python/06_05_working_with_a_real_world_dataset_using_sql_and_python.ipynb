# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Working with a real world data-set using SQL and Python
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Understand the dataset for Chicago Public School level performance
# *   Store the dataset in SQLite database.
# *   Retrieve metadata about tables and columns and query data from mixed case columns
# *   Solve example problems to practice your SQL skills including using built-in database functions

# %% [markdown]
# ## Chicago Public Schools - Progress Report Cards (2011-2012)
#
# The city of Chicago released a dataset showing all school level performance data used to create School Report Cards for the 2011-2012 school year. The dataset is available from the Chicago Data Portal: [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# This dataset includes a large number of metrics. Start by familiarizing yourself with the types of metrics in the database: [https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true](https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&download=true&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# **NOTE**:
#
# Do not download the dataset directly from City of Chicago portal. Instead download a static copy which is a more database friendly version from this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">link</a>.
#
# Now review some of its contents.

# %% [markdown]
# ### Connect to the database
#
# Let us now load the ipython-sql  extension and establish a connection with the database
#
# ##### The syntax for connecting to magic sql using sqllite is
#
#   **%sql sqlite://DatabaseName**
#
# where DatabaseName will be your **.db** file

# %%
import csv, sqlite3

con = sqlite3.connect("RealWorldData.db")
cur = con.cursor()

# %%
# !pip install pandas
# !pip install ipython-sql prettytable

import prettytable
prettytable.DEFAULT = 'DEFAULT'
# Out:
# Access is denied.
# Access is denied.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 get_ipython().system('pip install pandas')
#       2 get_ipython().system('pip install ipython-sql prettytable')
#       3
# ----> 4 import prettytable
#       5 prettytable.DEFAULT = 'DEFAULT'
#
# ModuleNotFoundError: No module named 'prettytable'

# %%
# !pip install ipython-sql
# %load_ext sql
# Out:
# Requirement already satisfied: ipython-sql in /opt/conda/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.12/site-packages (from ipython-sql) (3.17.0)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.12/site-packages (from ipython-sql) (8.31.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /opt/conda/lib/python3.12/site-packages (from ipython-sql) (2.0.37)
# Requirement already satisfied: sqlparse in /opt/conda/lib/python3.12/site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.12/site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.12/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.12/site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython->ipython-sql) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.12/site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/conda/lib/python3.12/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->ipython-sql) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->ipython-sql) (0.2.3)

# %%
# %sql sqlite:///RealWorldData.db

# %% [markdown]
# ### Store the dataset in a Table
#
# ##### In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet.
# ##### To analyze the data using SQL, it first needs to be stored in the database.
#
# ##### We will first read the csv files  from the given url  into pandas dataframes
#
# ##### Next we will be using the  df.to_sql() function to convert each csv file  to a table in sqlite  with the csv data loaded in it.

# %%
import pandas

df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv")

df.to_sql("chicago_public_schools_data", con, if_exists="replace", index=False, method="multi")
# Out:
# 566

# %% [markdown]
# Double-click **here** for the solution.
# <!--
#
# import pandas
#
# df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv")
# df.to_sql("CHICAGO_PUBLIC_SCHOOLS_DATA", con, if_exists='replace', index=False, method="multi")
#
# -->

# %% [markdown]
# ### Query the database system catalog to retrieve table metadata
#
# ##### You can verify that the table creation was successful by retrieving the list of all tables in your schema and checking whether the SCHOOLS table was created

# %%
# type in your query to retrieve list of all tables in the database
# %sql select name from sqlite_master where type="table";
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('CENSUS_DATA',), ('chicago_public_schools_data',)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# In sqlite the system catalog table called sqlite_master contains the table metadata
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution using SQLite:
#
# %sql SELECT name FROM sqlite_master WHERE type='table'
#
# -->

# %% [markdown]
# ### Query the database system catalog to retrieve column metadata
#
# ##### The SCHOOLS table contains a large number of columns. How many columns does this table have?

# %%
# type in your query to retrieve the number of columns in the SCHOOLS table
# %sql select count(name) from PRAGMA_TABLE_INFO("chicago_public_schools_data");
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(78,)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution SQLite:
# %sql SELECT count(name) FROM PRAGMA_TABLE_INFO('CHICAGO_PUBLIC_SCHOOLS_DATA');
#
# -->

# %% [markdown]
# Now retrieve the the list of columns in SCHOOLS table and their column type (datatype) and length.

# %%
# type in your query to retrieve all column names in the SCHOOLS table along with their datatypes and length
# %sql select name, type, length(type) from PRAGMA_TABLE_INFO("chicago_public_schools_data");
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('School_ID', 'INTEGER', 7),
#  ('NAME_OF_SCHOOL', 'TEXT', 4),
#  ('Elementary, Middle, or High School', 'TEXT', 4),
#  ('Street_Address', 'TEXT', 4),
#  ('City', 'TEXT', 4),
#  ('State', 'TEXT', 4),
#  ('ZIP_Code', 'INTEGER', 7),
#  ('Phone_Number', 'TEXT', 4),
#  ('Link', 'TEXT', 4),
#  ('Network_Manager', 'TEXT', 4),
#  ('Collaborative_Name', 'TEXT', 4),
#  ('Adequate_Yearly_Progress_Made_', 'TEXT', 4),
#  ('Track_Schedule', 'TEXT', 4),
#  ('CPS_Performance_Policy_Status', 'TEXT', 4),
#  ('CPS_Performance_Policy_Level', 'TEXT', 4),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'TEXT', 4),
#  ('Safety_Icon', 'TEXT', 4),
#  ('SAFETY_SCORE', 'REAL', 4),
#  ('Family_Involvement_Icon', 'TEXT', 4),
#  ('Family_Involvement_Score', 'TEXT', 4),
#  ('Environment_Icon', 'TEXT', 4),
#  ('Environment_Score', 'REAL', 4),
#  ('Instruction_Icon', 'TEXT', 4),
#  ('Instruction_Score', 'REAL', 4),
#  ('Leaders_Icon', 'TEXT', 4),
#  ('Leaders_Score', 'TEXT', 4),
#  ('Teachers_Icon', 'TEXT', 4),
#  ('Teachers_Score', 'TEXT', 4),
#  ('Parent_Engagement_Icon', 'TEXT', 4),
#  ('Parent_Engagement_Score', 'TEXT', 4),
#  ('Parent_Environment_Icon', 'TEXT', 4),
#  ('Parent_Environment_Score', 'TEXT', 4),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'TEXT', 4),
#  ('Rate_of_Misconducts__per_100_students_', 'REAL', 4),
#  ('Average_Teacher_Attendance', 'TEXT', 4),
#  ('Individualized_Education_Program_Compliance_Rate', 'TEXT', 4),
#  ('Pk_2_Literacy__', 'TEXT', 4),
#  ('Pk_2_Math__', 'TEXT', 4),
#  ('Gr3_5_Grade_Level_Math__', 'TEXT', 4),
#  ('Gr3_5_Grade_Level_Read__', 'TEXT', 4),
#  ('Gr3_5_Keep_Pace_Read__', 'TEXT', 4),
#  ('Gr3_5_Keep_Pace_Math__', 'TEXT', 4),
#  ('Gr6_8_Grade_Level_Math__', 'TEXT', 4),
#  ('Gr6_8_Grade_Level_Read__', 'TEXT', 4),
#  ('Gr6_8_Keep_Pace_Math_', 'TEXT', 4),
#  ('Gr6_8_Keep_Pace_Read__', 'TEXT', 4),
#  ('Gr_8_Explore_Math__', 'TEXT', 4),
#  ('Gr_8_Explore_Read__', 'TEXT', 4),
#  ('ISAT_Exceeding_Math__', 'REAL', 4),
#  ('ISAT_Exceeding_Reading__', 'REAL', 4),
#  ('ISAT_Value_Add_Math', 'REAL', 4),
#  ('ISAT_Value_Add_Read', 'REAL', 4),
#  ('ISAT_Value_Add_Color_Math', 'TEXT', 4),
#  ('ISAT_Value_Add_Color_Read', 'TEXT', 4),
#  ('Students_Taking__Algebra__', 'TEXT', 4),
#  ('Students_Passing__Algebra__', 'TEXT', 4),
#  ('9th Grade EXPLORE (2009)', 'TEXT', 4),
#  ('9th Grade EXPLORE (2010)', 'TEXT', 4),
#  ('10th Grade PLAN (2009)', 'TEXT', 4),
#  ('10th Grade PLAN (2010)', 'TEXT', 4),
#  ('Net_Change_EXPLORE_and_PLAN', 'TEXT', 4),
#  ('11th Grade Average ACT (2011)', 'TEXT', 4),
#  ('Net_Change_PLAN_and_ACT', 'TEXT', 4),
#  ('College_Eligibility__', 'TEXT', 4),
#  ('Graduation_Rate__', 'TEXT', 4),
#  ('College_Enrollment_Rate__', 'TEXT', 4),
#  ('COLLEGE_ENROLLMENT', 'INTEGER', 7),
#  ('General_Services_Route', 'INTEGER', 7),
#  ('Freshman_on_Track_Rate__', 'TEXT', 4),
#  ('X_COORDINATE', 'REAL', 4),
#  ('Y_COORDINATE', 'REAL', 4),
#  ('Latitude', 'REAL', 4),
#  ('Longitude', 'REAL', 4),
#  ('COMMUNITY_AREA_NUMBER', 'INTEGER', 7),
#  ('COMMUNITY_AREA_NAME', 'TEXT', 4),
#  ('Ward', 'INTEGER', 7),
#  ('Police_District', 'INTEGER', 7),
#  ('Location', 'TEXT', 4)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution
#
# %sql SELECT name,type,length(type) FROM PRAGMA_TABLE_INFO('CHICAGO_PUBLIC_SCHOOLS_DATA');
#
# -->

# %% [markdown]
# ### Questions
#
# 1.  Is the column name for the "SCHOOL ID" attribute in upper or mixed case?
# 2.  What is the name of "Community Area Name" column in your table? Does it have spaces?
# 3.  Are there any columns in whose names the spaces and paranthesis (round brackets) have been replaced by the underscore character "\_"?

# %%
"""
1. it is called School_ID
2. it is called COMMUNITY_AREA_NAME
3. none
"""
# Out:
# '\n1. it is called School_ID\n2. it is called COMMUNITY_AREA_NAME\n3. none\n'

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### How many Elementary Schools are in the dataset?

# %%
# %%sql
# select count("Elementary, Middle, or High School")
# from chicago_public_schools_data
# where "Elementary, Middle, or High School" = "ES";
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(462,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Which column specifies the school type e.g. 'ES', 'MS', 'HS'? ("Elementary School, Middle School, High School")
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Does the column name have mixed case, spaces or other special characters?
# If so, ensure you use double quotes around the "Name of the Column"
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from CHICAGO_PUBLIC_SCHOOLS_DATA where "Elementary, Middle, or High School"='ES'
#
# Correct answer: 462
#
# -->

# %% [markdown]
# ### Problem 2
#
# ##### What is the highest Safety Score?

# %%
# %%sql
# select max(SAFETY_SCORE)
# from chicago_public_schools_data;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(99.0,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Use the MAX() function
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Hint:
#
# %sql select MAX(Safety_Score) AS MAX_SAFETY_SCORE from CHICAGO_PUBLIC_SCHOOLS_DATA
#
# Correct answer: 99
# -->

# %% [markdown]
# ### Problem 3
#
# ##### Which schools have highest Safety Score?

# %%
# %%sql
# select NAME_OF_SCHOOL as highest_safety_score
# from chicago_public_schools_data
# where SAFETY_SCORE = (select max(SAFETY_SCORE) from chicago_public_schools_data);
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Abraham Lincoln Elementary School',),
#  ('Alexander Graham Bell Elementary School',),
#  ('Annie Keller Elementary Gifted Magnet School',),
#  ('Augustus H Burley Elementary School',),
#  ('Edgar Allan Poe Elementary Classical School',),
#  ('Edgebrook Elementary School',),
#  ('Ellen Mitchell Elementary School',),
#  ('James E McDade Elementary Classical School',),
#  ('James G Blaine Elementary School',),
#  ('LaSalle Elementary Language Academy',),
#  ('Mary E Courtenay Elementary Language Arts Center',),
#  ('Northside College Preparatory High School',),
#  ('Northside Learning Center High School',),
#  ('Norwood Park Elementary School',),
#  ('Oriole Park Elementary School',),
#  ('Sauganash Elementary School',),
#  ('Stephen Decatur Classical Elementary School',),
#  ('Talman Elementary School',),
#  ('Wildwood Elementary School',)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# In the previous problem we found out that the highest Safety Score is 99, so we can use that as an input in the where clause:
#
# %sql select Name_of_School, Safety_Score from CHICAGO_PUBLIC_SCHOOLS_DATA where Safety_Score = 99
#
# or, a better way:
#
# %sql select Name_of_School, Safety_Score from CHICAGO_PUBLIC_SCHOOLS_DATA where \
#   Safety_Score= (select MAX(Safety_Score) from CHICAGO_PUBLIC_SCHOOLS_DATA)
#
#
# Correct answer: several schools with with Safety Score of 99.
# -->

# %% [markdown]
# ### Problem 4
#
# ##### What are the top 10 schools with the highest "Average Student Attendance"?

# %%
# %%sql
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
# from chicago_public_schools_data
# order by AVERAGE_STUDENT_ATTENDANCE desc nulls last
# limit 10;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Name_of_School, Average_Student_Attendance from CHICAGO_PUBLIC_SCHOOLS_DATA \
#     order by Average_Student_Attendance desc nulls last limit 10
#
# -->

# %% [markdown]
# ### Problem 5
#
# ##### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %%
# %%sql
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
# from chicago_public_schools_data
# where AVERAGE_STUDENT_ATTENDANCE not null
# order by AVERAGE_STUDENT_ATTENDANCE asc
# limit 5;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from CHICAGO_PUBLIC_SCHOOLS_DATA \
#      order by Average_Student_Attendance \
#      LIMIT 5
#
# -->

# %% [markdown]
# ### Problem 6
#
# ##### Now remove the '%' sign from the above result set for Average Student Attendance column

# %%
# %%sql
# select NAME_OF_SCHOOL, replace(AVERAGE_STUDENT_ATTENDANCE, "%", "") as avg_student_attendance
# from chicago_public_schools_data
# where AVERAGE_STUDENT_ATTENDANCE not null
# order by AVERAGE_STUDENT_ATTENDANCE asc
# limit 5;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Use the REPLACE() function to replace '%' with ''
#
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Hint:
#
# %sql SELECT Name_of_School, REPLACE(Average_Student_Attendance, '%', '') \
#      from CHICAGO_PUBLIC_SCHOOLS_DATA \
#      order by Average_Student_Attendance \
#      LIMIT 5
#
# -->

# %% [markdown]
# ### Problem 7
#
# ##### Which Schools have Average Student Attendance lower than 70%?

# %%
# %%sql
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
# from chicago_public_schools_data
# where cast(replace(AVERAGE_STUDENT_ATTENDANCE, "%", "") as double) < 70
# order by AVERAGE_STUDENT_ATTENDANCE
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# The datatype of the "Average_Student_Attendance" column is varchar.
# So you cannot use it as is in the where clause for a numeric comparison.
# First use the CAST() function to cast it as a DECIMAL or DOUBLE
# e.g. CAST("Column_Name" as DOUBLE)
#
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Don't forget the '%' age sign needs to be removed before casting
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from CHICAGO_PUBLIC_SCHOOLS_DATA \
#      where CAST ( REPLACE(Average_Student_Attendance, '%', '') AS DOUBLE ) < 70 \
#      order by Average_Student_Attendance
#
#
# -->

# %% [markdown]
# ### Problem 8
#
# ##### Get the total College Enrollment for each Community Area

# %%
# %%sql
# select COMMUNITY_AREA_NAME, sum(COLLEGE_ENROLLMENT) as total_enrollment
# from chicago_public_schools_data
# group by COMMUNITY_AREA_NAME;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('ALBANY PARK', 6864),
#  ('ARCHER HEIGHTS', 4823),
#  ('ARMOUR SQUARE', 1458),
#  ('ASHBURN', 6483),
#  ('AUBURN GRESHAM', 4175),
#  ('AUSTIN', 10933),
#  ('AVALON PARK', 1522),
#  ('AVONDALE', 3640),
#  ('BELMONT CRAGIN', 14386),
#  ('BEVERLY', 1636),
#  ('BRIDGEPORT', 3167),
#  ('BRIGHTON PARK', 9647),
#  ('BURNSIDE', 549),
#  ('CALUMET HEIGHTS', 1568),
#  ('CHATHAM', 5042),
#  ('CHICAGO LAWN', 7086),
#  ('CLEARING', 2085),
#  ('DOUGLAS', 4670),
#  ('DUNNING', 4568),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('EDGEWATER', 4600),
#  ('EDISON PARK', 910),
#  ('ENGLEWOOD', 6832),
#  ('FOREST GLEN', 1431),
#  ('FULLER PARK', 531),
#  ('GAGE PARK', 9915),
#  ('GARFIELD RIDGE', 4552),
#  ('GRAND BOULEVARD', 2809),
#  ('GREATER GRAND CROSSING', 4051),
#  ('HEGEWISCH', 963),
#  ('HERMOSA', 3975),
#  ('HUMBOLDT PARK', 8620),
#  ('HYDE PARK', 1930),
#  ('IRVING PARK', 7764),
#  ('JEFFERSON PARK', 1755),
#  ('KENWOOD', 4287),
#  ('LAKE VIEW', 7055),
#  ('LINCOLN PARK', 5615),
#  ('LINCOLN SQUARE', 4132),
#  ('LOGAN SQUARE', 7351),
#  ('LOOP', 871),
#  ('LOWER WEST SIDE', 7257),
#  ('MCKINLEY PARK', 1552),
#  ('MONTCLARE', 1317),
#  ('MORGAN PARK', 3271),
#  ('MOUNT GREENWOOD', 2091),
#  ('NEAR NORTH SIDE', 3362),
#  ('NEAR SOUTH SIDE', 1378),
#  ('NEAR WEST SIDE', 7975),
#  ('NEW CITY', 7922),
#  ('NORTH CENTER', 7541),
#  ('NORTH LAWNDALE', 5146),
#  ('NORTH PARK', 4210),
#  ('NORWOOD PARK', 6469),
#  ('OAKLAND', 140),
#  ('OHARE', 786),
#  ('PORTAGE PARK', 6954),
#  ('PULLMAN', 1620),
#  ('RIVERDALE', 1547),
#  ('ROGERS PARK', 4068),
#  ('ROSELAND', 7020),
#  ('SOUTH CHICAGO', 4043),
#  ('SOUTH DEERING', 1859),
#  ('SOUTH LAWNDALE', 14793),
#  ('SOUTH SHORE', 4543),
#  ('UPTOWN', 4388),
#  ('WASHINGTON HEIGHTS', 4006),
#  ('WASHINGTON PARK', 2648),
#  ('WEST ELSDON', 3700),
#  ('WEST ENGLEWOOD', 5946),
#  ('WEST GARFIELD PARK', 2622),
#  ('WEST LAWN', 4207),
#  ('WEST PULLMAN', 3240),
#  ('WEST RIDGE', 8197),
#  ('WEST TOWN', 9429),
#  ('WOODLAWN', 4206)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Verify the exact name of the Enrollment column in the database
# Use the SUM() function to add up the Enrollments for each Community Area
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Don't forget to group by the Community Area
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
#    from CHICAGO_PUBLIC_SCHOOLS_DATA \
#    group by Community_Area_Name
#
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order

# %%
# %%sql
# select COMMUNITY_AREA_NAME, sum(COLLEGE_ENROLLMENT) as total_enrollment
# from chicago_public_schools_data
# group by COMMUNITY_AREA_NAME
# order by total_enrollment asc
# limit 5;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Order the previous query and limit the number of rows you fetch
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
#    from CHICAGO_PUBLIC_SCHOOLS_DATA \
#    group by Community_Area_Name \
#    order by TOTAL_ENROLLMENT asc \
#    LIMIT 5
#
# -->

# %% [markdown]
# ### Problem 10
#
# ##### List 5 schools with lowest safety score.

# %%
# %%sql
# select NAME_OF_SCHOOL, SAFETY_SCORE
# from chicago_public_schools_data
# where SAFETY_SCORE not null
# order by SAFETY_SCORE asc
# limit 5;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Edmond Burke Elementary School', 1.0),
#  ("Luke O'Toole Elementary School", 5.0),
#  ('George W Tilton Elementary School', 6.0),
#  ('Foster Park Elementary School', 11.0),
#  ('Emil G Hirsch Metropolitan High School', 13.0)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution SQLite:
#
# %sql SELECT name_of_school, safety_score \
# FROM CHICAGO_PUBLIC_SCHOOLS_DATA  where safety_score !='None' \
# ORDER BY safety_score \
# LIMIT 5
#
# -->

# %% [markdown]
# ### Problem 11
#
# ##### Get the hardship index for the community area of the school which has College Enrollment of 4368

# %%
df2 = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv")
df2.to_sql("CENSUS_DATA", con, if_exists="replace", index=False,method="multi")
# Out:
# 78

# %%
# %sql select name, type, length(type) from PRAGMA_TABLE_INFO("CENSUS_DATA");
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('COMMUNITY_AREA_NUMBER', 'REAL', 4),
#  ('COMMUNITY_AREA_NAME', 'TEXT', 4),
#  ('PERCENT_OF_HOUSING_CROWDED', 'REAL', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'REAL', 4),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'REAL', 4),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'REAL', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'REAL', 4),
#  ('PER_CAPITA_INCOME', 'INTEGER', 7),
#  ('HARDSHIP_INDEX', 'REAL', 4)]

# %%
# %%sql
# select cpsd.COMMUNITY_AREA_NAME, cpsd.NAME_OF_SCHOOL, cpsd.COLLEGE_ENROLLMENT, cd.HARDSHIP_INDEX from CENSUS_DATA as cd, chicago_public_schools_data as cpsd
# where cd.community_area_number = cpsd.community_area_number and college_enrollment = 4368
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('NORTH CENTER', 'Albert G Lane Technical High School', 4368, 6.0)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist. If the CHICAGO_SOCIOECONOMIC_DATA table does not exists, please execute the following code beforehand.
#
# df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv")
# df.to_sql("CENSUS_DATA", con, if_exists='replace', index=False,method="multi")
#
#
# %%sql
# select hardship_index from CENSUS_DATA CD, CHICAGO_PUBLIC_SCHOOLS_DATA CPS
# where CD.community_area_number = CPS.community_area_number
# and college_enrollment = 4368
#
#
# -->

# %% [markdown]
# ### Problem 12
#
# ##### Get the hardship index for the community area which has the highest value for College Enrollment

# %%
# %%sql
# select cd.COMMUNITY_AREA_NUMBER, cd.COMMUNITY_AREA_NAME, cd.HARDSHIP_INDEX, ch.NAME_OF_SCHOOL, ch.COLLEGE_ENROLLMENT
# from CENSUS_DATA as cd, chicago_public_schools_data as ch
# where cd.COMMUNITY_AREA_NUMBER in (
#     select COMMUNITY_AREA_NUMBER
#     from chicago_public_schools_data
#     where COLLEGE_ENROLLMENT = (select max(COLLEGE_ENROLLMENT) from chicago_public_schools_data)
#         and COLLEGE_ENROLLMENT not null
#     );
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(5.0, 'North Center', 6.0, 'Abraham Lincoln Elementary School', 813),
#  (5.0, 'North Center', 6.0, 'Adam Clayton Powell Paideia Community Academy Elementary School', 521),
#  (5.0, 'North Center', 6.0, 'Adlai E Stevenson Elementary School', 1324),
#  (5.0, 'North Center', 6.0, 'Agustin Lara Elementary Academy', 556),
#  (5.0, 'North Center', 6.0, 'Air Force Academy High School', 302),
#  (5.0, 'North Center', 6.0, 'Albany Park Multicultural Academy', 266),
#  (5.0, 'North Center', 6.0, 'Albert G Lane Technical High School', 4368),
#  (5.0, 'North Center', 6.0, 'Albert R Sabin Elementary Magnet School', 620),
#  (5.0, 'North Center', 6.0, 'Alcott High School for the Humanities', 232),
#  (5.0, 'North Center', 6.0, 'Alessandro Volta Elementary School', 1023),
#  (5.0, 'North Center', 6.0, 'Alexander Graham Bell Elementary School', 998),
#  (5.0, 'North Center', 6.0, 'Alexander Graham Elementary School', 476),
#  (5.0, 'North Center', 6.0, 'Alexander Hamilton Elementary School', 307),
#  (5.0, 'North Center', 6.0, 'Alexander von Humboldt Elementary School', 398),
#  (5.0, 'North Center', 6.0, 'Alex Haley Elementary Academy', 525),
#  (5.0, 'North Center', 6.0, 'Alfred David Kohn Elementary School', 428),
#  (5.0, 'North Center', 6.0, 'Alfred Nobel Elementary School', 801),
#  (5.0, 'North Center', 6.0, 'Alice L Barnard Computer Math & Science Center Elementary School', 274),
#  (5.0, 'North Center', 6.0, 'Al Raby High School', 551),
#  (5.0, 'North Center', 6.0, 'Ambrose Plamondon Elementary School', 171),
#  (5.0, 'North Center', 6.0, 'Amelia Earhart Options for Knowledge Elementary School', 264),
#  (5.0, 'North Center', 6.0, 'Ames Middle School', 586),
#  (5.0, 'North Center', 6.0, 'Amos Alonzo Stagg Elementary School', 539),
#  (5.0, 'North Center', 6.0, 'Ana Roque de Duprey Elementary School', 114),
#  (5.0, 'North Center', 6.0, 'Andrew Carnegie Elementary School', 730),
#  (5.0, 'North Center', 6.0, 'Andrew Jackson Elementary Language Academy', 556),
#  (5.0, 'North Center', 6.0, 'Anna R. Langford Community Academy', 339),
#  (5.0, 'North Center', 6.0, 'Annie Keller Elementary Gifted Magnet School', 245),
#  (5.0, 'North Center', 6.0, 'A.N. Pritzker School', 669),
#  (5.0, 'North Center', 6.0, 'Anthony Overton Elementary School', 436),
#  (5.0, 'North Center', 6.0, 'Ariel Elementary Community Academy', 550),
#  (5.0, 'North Center', 6.0, 'Arna Wendell Bontemps Elementary School', 345),
#  (5.0, 'North Center', 6.0, 'Arnold Mireles Elementary Academy', 905),
#  (5.0, 'North Center', 6.0, 'Arthur A Libby Elementary School', 539),
#  (5.0, 'North Center', 6.0, 'Arthur Dixon Elementary School', 652),
#  (5.0, 'North Center', 6.0, 'Arthur E Canty Elementary School', 784),
#  (5.0, 'North Center', 6.0, 'Arthur R Ashe Elementary School', 459),
#  (5.0, 'North Center', 6.0, 'Asa Philip Randolph Elementary School', 573),
#  (5.0, 'North Center', 6.0, 'Ashburn Community Elementary School', 490),
#  (5.0, 'North Center', 6.0, 'Augustus H Burley Elementary School', 572),
#  (5.0, 'North Center', 6.0, 'Austin Business and Entrepreneurship Academy High School', 316),
#  (5.0, 'North Center', 6.0, 'Austin O Sexton Elementary School', 337),
#  (5.0, 'North Center', 6.0, 'Austin Polytechnical Academy High School', 250),
#  (5.0, 'North Center', 6.0, 'Avalon Park Elementary School', 398),
#  (5.0, 'North Center', 6.0, 'Barbara Vick Early Childhood & Family Center', 204),
#  (5.0, 'North Center', 6.0, 'Belmont-Cragin Elementary School', 634),
#  (5.0, 'North Center', 6.0, 'Benito Juarez Community Academy High School', 1683),
#  (5.0, 'North Center', 6.0, 'Benjamin Banneker Elementary School', 302),
#  (5.0, 'North Center', 6.0, 'Benjamin E Mays Elementary Academy', 301),
#  (5.0, 'North Center', 6.0, 'Bernhard Moos Elementary School', 429),
#  (5.0, 'North Center', 6.0, 'Betsy Ross Elementary School', 350),
#  (5.0, 'North Center', 6.0, 'Beulah Shoesmith Elementary School', 325),
#  (5.0, 'North Center', 6.0, 'Blair Early Childhood Center', 137),
#  (5.0, 'North Center', 6.0, 'Bret Harte Elementary School', 340),
#  (5.0, 'North Center', 6.0, 'Brian Piccolo Elementary Specialty School', 549),
#  (5.0, 'North Center', 6.0, 'Brighton Park Elementary School', 691),
#  (5.0, 'North Center', 6.0, 'Bronzeville Scholastic Academy High School', 550),
#  (5.0, 'North Center', 6.0, 'Burnham Elementary Inclusive Academy', 286),
#  (5.0, 'North Center', 6.0, 'Burnside Elementary Scholastic Academy', 766),
#  (5.0, 'North Center', 6.0, 'Calmeca Academy of Fine Arts and Dual Language', 792),
#  (5.0, 'North Center', 6.0, 'Carl Schurz High School', 2366),
#  (5.0, 'North Center', 6.0, 'Carl von Linne Elementary School', 644),
#  (5.0, 'North Center', 6.0, 'Carrie Jacobs Bond Elementary School', 343),
#  (5.0, 'North Center', 6.0, 'Carroll-Rosenwald Specialty Elementary School', 537),
#  (5.0, 'North Center', 6.0, 'Carter G Woodson South Elementary School', 329),
#  (5.0, 'North Center', 6.0, 'Cesar E Chavez Multicultural Academic Center Elementary School', 915),
#  (5.0, 'North Center', 6.0, 'Charles Allen Prosser Career Academy High School', 1415),
#  (5.0, 'North Center', 6.0, 'Charles Evans Hughes Elementary School', 315),
#  (5.0, 'North Center', 6.0, 'Charles Gates Dawes Elementary School', 1032),
#  (5.0, 'North Center', 6.0, 'Charles G Hammond Elementary School', 446),
#  (5.0, 'North Center', 6.0, 'Charles H Wacker Elementary School', 246),
#  (5.0, 'North Center', 6.0, 'Charles Kozminski Elementary Community Academy', 403),
#  (5.0, 'North Center', 6.0, 'Charles N Holden Elementary School', 600),
#  (5.0, 'North Center', 6.0, 'Charles P Caldwell Academy of Math & Science Elementary School', 291),
#  (5.0, 'North Center', 6.0, 'Charles P Steinmetz Academic Centre High School', 1890),
#  (5.0, 'North Center', 6.0, 'Charles R Darwin Elementary School', 622),
#  (5.0, 'North Center', 6.0, 'Charles R Henderson Elementary School', 407),
#  (5.0, 'North Center', 6.0, 'Charles S Brownell Elementary School', 310),
#  (5.0, 'North Center', 6.0, 'Charles S Deneen Elementary School', 551),
#  (5.0, 'North Center', 6.0, 'Charles Sumner  Math & Science Community Acad Elementary School', 430),
#  (5.0, 'North Center', 6.0, 'Charles W Earle Elementary School', 331),
#  (5.0, 'North Center', 6.0, 'Chicago Academy Elementary School', 601),
#  (5.0, 'North Center', 6.0, 'Chicago Academy High School', 502),
#  (5.0, 'North Center', 6.0, 'Chicago High School for Agricultural Sciences', 579),
#  (5.0, 'North Center', 6.0, 'Chicago Military Academy High School', 483),
#  (5.0, 'North Center', 6.0, 'Chicago Vocational Career Academy High School', 833),
#  (5.0, 'North Center', 6.0, 'Christian Ebinger Elementary School', 650),
#  (5.0, 'North Center', 6.0, 'Christian Fenger Academy High School', 688),
#  (5.0, 'North Center', 6.0, 'Christopher Columbus Elementary School', 309),
#  (5.0, 'North Center', 6.0, 'Clara Barton Elementary School', 602),
#  (5.0, 'North Center', 6.0, 'Claremont Academy Elementary School', 531),
#  (5.0, 'North Center', 6.0, 'Collins Academy High School', 409),
#  (5.0, 'North Center', 6.0, 'Columbia Explorers Elementary Academy', 1038),
#  (5.0, 'North Center', 6.0, 'Countee Cullen Elementary School', 233),
#  (5.0, 'North Center', 6.0, 'Crispus Attucks Elementary School', 274),
#  (5.0, 'North Center', 6.0, 'Crown Community Academy of Fine Arts Center Elementary School', 298),
#  (5.0, 'North Center', 6.0, 'Cyrus H McCormick Elementary School', 894),
#  (5.0, 'North Center', 6.0, 'Daniel Boone Elementary School', 752),
#  (5.0, 'North Center', 6.0, 'Daniel C Beard Elementary School', 160),
#  (5.0, 'North Center', 6.0, 'Daniel Hale Williams Prep School of Medicine', 324),
#  (5.0, 'North Center', 6.0, 'Daniel J Corkery Elementary School', 631),
#  (5.0, 'North Center', 6.0, 'Daniel R Cameron Elementary School', 828),
#  (5.0, 'North Center', 6.0, 'Daniel S Wentworth Elementary School', 365),
#  (5.0, 'North Center', 6.0, 'Daniel Webster Elementary School', 370),
#  (5.0, 'North Center', 6.0, 'David G Farragut Career Academy High School', 1456),
#  (5.0, 'North Center', 6.0, 'DeVry University Advantage Academy High School', 200),
#  (5.0, 'North Center', 6.0, 'Dewey Elementary Academy of Fine Arts', 357),
#  (5.0, 'North Center', 6.0, 'DeWitt Clinton Elementary School', 1139),
#  (5.0, 'North Center', 6.0, 'Disney II Magnet School', 363),
#  (5.0, 'North Center', 6.0, 'Donald Morrill Math & Science Elementary School', 823),
#  (5.0, 'North Center', 6.0, 'Douglas Taylor Elementary School', 632),
#  (5.0, 'North Center', 6.0, 'Dr Jorge Prieto Math and Science', 1001),
#  (5.0, 'North Center', 6.0, 'Dr  Martin Luther King  Jr  College Prep High School', 915),
#  (5.0, 'North Center', 6.0, 'Dumas Technology Academy', 381),
#  (5.0, 'North Center', 6.0, 'Dunne Technology Academy', 310),
#  (5.0, 'North Center', 6.0, 'Durkin Park Elementary School', 543),
#  (5.0, 'North Center', 6.0, 'Dvorak Technology Academy', 556),
#  (5.0, 'North Center', 6.0, 'Dyett High School', 318),
#  (5.0, 'North Center', 6.0, 'Edgar Allan Poe Elementary Classical School', 192),
#  (5.0, 'North Center', 6.0, 'Edgebrook Elementary School', 468),
#  (5.0, 'North Center', 6.0, 'Edison Park Elementary School', 431),
#  (5.0, 'North Center', 6.0, 'Edmond Burke Elementary School', 244),
#  (5.0, 'North Center', 6.0, 'Edward A Bouchet Math & Science Academy Elementary School', 783),
#  (5.0, 'North Center', 6.0, 'Edward Beasley Elementary Magnet Academic Center', 1365),
#  (5.0, 'North Center', 6.0, 'Edward C Delano Elementary School', 414),
#  (5.0, 'North Center', 6.0, 'Edward Coles Elementary Language Academy', 554),
#  (5.0, 'North Center', 6.0, 'Edward Everett Elementary School', 321),
#  (5.0, 'North Center', 6.0, 'Edward Jenner Elementary Academy of the Arts', 314),
#  (5.0, 'North Center', 6.0, 'Edward K Ellington Elementary School', 377),
#  (5.0, 'North Center', 6.0, 'Edward N Hurley Elementary School', 830),
#  (5.0, 'North Center', 6.0, 'Edward Tilden Career Community Academy High School', 461),
#  (5.0, 'North Center', 6.0, 'Edward White Elementary Career Academy', 138),
#  (5.0, 'North Center', 6.0, 'Edwin G Foreman High School', 1716),
#  (5.0, 'North Center', 6.0, 'Elaine O Goodlow Elementary Magnet School', 419),
#  (5.0, 'North Center', 6.0, 'Elihu Yale Elementary School', 182),
#  (5.0, 'North Center', 6.0, 'Eli Whitney Elementary School', 1133),
#  (5.0, 'North Center', 6.0, 'Elizabeth H Sutherland Elementary School', 762),
#  (5.0, 'North Center', 6.0, 'Elizabeth Peabody Elementary School', 289),
#  (5.0, 'North Center', 6.0, 'Eliza Chappell Elementary School', 451),
#  (5.0, 'North Center', 6.0, 'Ella Flagg Young Elementary School', 1111),
#  (5.0, 'North Center', 6.0, 'Ellen H Richards Career Academy High School', 473),
#  (5.0, 'North Center', 6.0, 'Ellen Mitchell Elementary School', 344),
#  (5.0, 'North Center', 6.0, 'Emil G Hirsch Metropolitan High School', 458),
#  (5.0, 'North Center', 6.0, 'Emiliano Zapata Elementary Academy', 988),
#  (5.0, 'North Center', 6.0, 'Emmett Louis Till Math and Science Academy', 471),
#  (5.0, 'North Center', 6.0, 'Enrico Fermi Elementary School', 238),
#  (5.0, 'North Center', 6.0, 'Enrico Tonti Elementary School', 1021),
#  (5.0, 'North Center', 6.0, 'Eric Solorio Academy High School', 581),
#  (5.0, 'North Center', 6.0, 'Ernst Prussing Elementary School', 672),
#  (5.0, 'North Center', 6.0, 'Esmond Elementary School', 342),
#  (5.0, 'North Center', 6.0, 'Eugene Field Elementary School', 375),
#  (5.0, 'North Center', 6.0, 'Everett McKinley Dirksen Elementary School', 786),
#  (5.0, 'North Center', 6.0, 'Evergreen Academy Middle School', 389),
#  (5.0, 'North Center', 6.0, 'Fairfield Elementary Academy', 604),
#  (5.0, 'North Center', 6.0, 'Federico Garcia Lorca Elementary School', 860),
#  (5.0, 'North Center', 6.0, 'Wilma Rudolph Elementary Learning Center', 100),
#  (5.0, 'North Center', 6.0, 'Ferdinand Peck Elementary School', 1560),
#  (5.0, 'North Center', 6.0, 'Fernwood Elementary School', 344),
#  (5.0, 'North Center', 6.0, 'Florence B Price Elementary School', 112),
#  (5.0, 'North Center', 6.0, 'Florence Nightingale Elementary School', 1382),
#  (5.0, 'North Center', 6.0, 'Fort Dearborn Elementary School', 478),
#  (5.0, 'North Center', 6.0, 'Foster Park Elementary School', 418),
#  (5.0, 'North Center', 6.0, 'Francisco I Madero Middle School', 314),
#  (5.0, 'North Center', 6.0, 'Francis M McKay Elementary School', 891),
#  (5.0, 'North Center', 6.0, 'Francis Parkman Elementary School', 224),
#  (5.0, 'North Center', 6.0, 'Francis Scott Key Elementary School', 301),
#  (5.0, 'North Center', 6.0, 'Francis W Parker Elementary Community Academy', 808),
#  (5.0, 'North Center', 6.0, 'Frank I Bennett Elementary School', 504),
#  (5.0, 'North Center', 6.0, 'Frank L Gillespie Elementary School', 609),
#  (5.0, 'North Center', 6.0, 'Franklin Elementary Fine Arts Center', 363),
#  (5.0, 'North Center', 6.0, 'Frank W Gunsaulus Elementary Scholastic Academy', 867),
#  (5.0, 'North Center', 6.0, 'Frank W Reilly Elementary School', 1195),
#  (5.0, 'North Center', 6.0, 'Franz Peter Schubert Elementary School', 949),
#  (5.0, 'North Center', 6.0, 'Frazier Prospective IB Magnet Elementary School', 220),
#  (5.0, 'North Center', 6.0, 'Frederic Chopin Elementary School', 269),
#  (5.0, 'North Center', 6.0, 'Frederick A Douglass Academy High School', 354),
#  (5.0, 'North Center', 6.0, 'Frederick Funston Elementary School', 619),
#  (5.0, 'North Center', 6.0, 'Frederick Stock Elementary School', 260),
#  (5.0, 'North Center', 6.0, 'Friedrich Ludwig Jahn Elementary School', 495),
#  (5.0, 'North Center', 6.0, 'Friedrich W von Steuben Metropolitan Science High School', 1636),
#  (5.0, 'North Center', 6.0, 'Gage Park High School', 1052),
#  (5.0, 'North Center', 6.0, 'Galileo Math & Science Scholastic Academy Elementary School', 606),
#  (5.0, 'North Center', 6.0, 'Garrett A Morgan Elementary School', 237),
#  (5.0, 'North Center', 6.0, 'Genevieve Melody Elementary School', 315),
#  (5.0, 'North Center', 6.0, 'George Armstrong International Studies Elementary School', 1509),
#  (5.0, 'North Center', 6.0, 'George B McClellan Elementary School', 283),
#  (5.0, 'North Center', 6.0, 'George B Swift Elementary Specialty School', 709),
#  (5.0, 'North Center', 6.0, 'George F Cassell Elementary School', 358),
#  (5.0, 'North Center', 6.0, 'George H Corliss High School', 621),
#  (5.0, 'North Center', 6.0, 'George Leland Elementary School', 182),
#  (5.0, 'North Center', 6.0, 'George Manierre Elementary School', 396),
#  (5.0, 'North Center', 6.0, 'George M Pullman Elementary School', 259),
#  (5.0, 'North Center', 6.0, 'George Rogers Clark Elementary School', 297),
#  (5.0, 'North Center', 6.0, 'George Washington Carver Military Academy High School', 532),
#  (5.0, 'North Center', 6.0, 'George Washington Carver Primary School', 546),
#  (5.0, 'North Center', 6.0, 'George Washington Elementary School', 813),
#  (5.0, 'North Center', 6.0, 'George Washington High School', 1524),
#  (5.0, 'North Center', 6.0, 'George W Curtis Elementary School', 504),
#  (5.0, 'North Center', 6.0, 'George Westinghouse High School', 828),
#  (5.0, 'North Center', 6.0, 'George W Tilton Elementary School', 321),
#  (5.0, 'North Center', 6.0, 'Gerald Delgado Kanoon Elementary Magnet School', 713),
#  (5.0, 'North Center', 6.0, 'Graeme Stewart Elementary School', 280),
#  (5.0, 'North Center', 6.0, 'Granville T Woods Math & Science Academy Elementary School', 402),
#  (5.0, 'North Center', 6.0, 'Greater Lawndale High School For Social Justice', 371),
#  (5.0, 'North Center', 6.0, 'Grover Cleveland Elementary School', 688),
#  (5.0, 'North Center', 6.0, 'Guglielmo Marconi Elementary Community Academy', 245),
#  (5.0, 'North Center', 6.0, 'Gurdon S Hubbard High School', 1672),
#  (5.0, 'North Center', 6.0, 'Gwendolyn Brooks College Preparatory Academy High School', 783),
#  (5.0, 'North Center', 6.0, 'Hannah G Solomon Elementary School', 363),
#  (5.0, 'North Center', 6.0, 'Hanson Park Elementary School', 1499),
#  (5.0, 'North Center', 6.0, 'Harold Washington Elementary School', 549),
#  (5.0, 'North Center', 6.0, 'Harriet Beecher Stowe Elementary School', 893),
#  (5.0, 'North Center', 6.0, 'Harriet E Sayre Elementary Language Academy', 605),
#  (5.0, 'North Center', 6.0, 'Hawthorne Elementary Scholastic Academy', 569),
#  (5.0, 'North Center', 6.0, 'Helen M Hefferan Elementary School', 259),
#  (5.0, 'North Center', 6.0, 'Helen Peirce International Studies Elementary School', 977),
#  (5.0, 'North Center', 6.0, 'Helge A Haugan Elementary School', 1299),
#  (5.0, 'North Center', 6.0, 'Henry Clay Elementary School', 633),
#  (5.0, 'North Center', 6.0, 'Henry D Lloyd Elementary School', 1334),
#  (5.0, 'North Center', 6.0, 'Henry H Nash Elementary School', 393),
#  (5.0, 'North Center', 6.0, 'Henry O Tanner Elementary School', 448),
#  (5.0, 'North Center', 6.0, 'Henry R Clissold Elementary School', 588),
#  (5.0, 'North Center', 6.0, 'High School of Leadership at South Shore', 731),
#  (5.0, 'North Center', 6.0, 'Hiram H Belding Elementary School', 672),
#  (5.0, 'North Center', 6.0, 'Hope College Preparatory High School', 561),
#  (5.0, 'North Center', 6.0, 'Horace Greeley Elementary School', 611),
#  (5.0, 'North Center', 6.0, 'Horace Mann Elementary School', 472),
#  (5.0, 'North Center', 6.0, 'Horatio May Elementary Community Academy', 458),
#  (5.0, 'North Center', 6.0, 'Hyde Park Academy High School', 1518),
#  (5.0, 'North Center', 6.0, 'Hyman G Rickover Naval Academy High School', 423),
#  (5.0, 'North Center', 6.0, 'Ida B Wells Preparatory Elementary Academy', 215),
#  (5.0, 'North Center', 6.0, 'Ignance Paderewski Elementary Learning Academy', 130),
#  (5.0, 'North Center', 6.0, 'Infinity Math Science and Technology High School', 388),
#  (5.0, 'North Center', 6.0, 'Inter-American Elementary Magnet School', 690),
#  (5.0, 'North Center', 6.0, 'Ira F Aldridge Elementary School', 285),
#  (5.0, 'North Center', 6.0, 'Irene C. Hernandez Middle School for the Advancement of Science', 970),
#  (5.0, 'North Center', 6.0, 'Irma C Ruiz Elementary School', 916),
#  (5.0, 'North Center', 6.0, 'Irvin C Mollison Elementary School', 244),
#  (5.0, 'North Center', 6.0, "Isabelle C O'Keeffe Elementary School", 575),
#  (5.0, 'North Center', 6.0, 'Jackie Robinson Elementary School', 140),
#  (5.0, 'North Center', 6.0, 'Jacob Beidler Elementary School', 411),
#  (5.0, 'North Center', 6.0, 'Jacqueline B Vaughn Occupational High School', 203),
#  (5.0, 'North Center', 6.0, 'James B Farnsworth Elementary School', 574),
#  (5.0, 'North Center', 6.0, 'James B McPherson Elementary School', 695),
#  (5.0, 'North Center', 6.0, 'James E McDade Elementary Classical School', 199),
#  (5.0, 'North Center', 6.0, 'James G Blaine Elementary School', 923),
#  (5.0, 'North Center', 6.0, 'James Hedges Elementary School', 845),
#  (5.0, 'North Center', 6.0, 'James Madison Elementary School', 317),
#  (5.0, 'North Center', 6.0, 'James Monroe Elementary School', 1125),
#  (5.0, 'North Center', 6.0, 'James N Thorp Elementary School', 449),
#  (5.0, 'North Center', 6.0, 'James Otis Elementary School', 491),
#  (5.0, 'North Center', 6.0, 'James R Doolittle Jr Elementary School', 306),
#  (5.0, 'North Center', 6.0, 'James Russell Lowell Elementary School', 593),
#  (5.0, 'North Center', 6.0, 'James Shields Elementary School', 1834),
#  (5.0, 'North Center', 6.0, 'James Wadsworth Elementary School', 277),
#  (5.0, 'North Center', 6.0, 'James Ward Elementary School', 492),
#  (5.0, 'North Center', 6.0, 'James Weldon Johnson Elementary School', 365),
#  (5.0, 'North Center', 6.0, 'Jane Addams Elementary School', 928),
#  (5.0, 'North Center', 6.0, 'Jane A Neil Elementary School', 306),
#  (5.0, 'North Center', 6.0, 'Jean Baptiste Beaubien Elementary School', 1181),
#  (5.0, 'North Center', 6.0, 'Jean D Lafayette Elementary School', 474),
#  (5.0, 'North Center', 6.0, 'Jensen Elementary Scholastic Academy', 364),
#  (5.0, 'North Center', 6.0, 'Jesse Owens Elementary Community Academy', 340),
#  (5.0, 'North Center', 6.0, 'Jesse Sherwood Elementary School', 355),
#  (5.0, 'North Center', 6.0, 'Johann W von Goethe Elementary School', 786),
#  (5.0, 'North Center', 6.0, 'John A Walsh Elementary School', 501),
#  (5.0, 'North Center', 6.0, 'John Barry Elementary School', 800),
#  (5.0, 'North Center', 6.0, 'John B Drake Elementary School', 249),
#  (5.0, 'North Center', 6.0, 'John B Murphy Elementary School', 638),
#  (5.0, 'North Center', 6.0, 'John Calhoun North Elementary School', 328),
#  (5.0, 'North Center', 6.0, 'John C Burroughs Elementary School', 510),
#  (5.0, 'North Center', 6.0, 'John C Coonley Elementary School', 668),
#  (5.0, 'North Center', 6.0, 'John C Dore Elementary School', 590),
#  (5.0, 'North Center', 6.0, 'John Charles Haines Elementary School', 664),
#  (5.0, 'North Center', 6.0, 'John D Shoop Math-Science Technical Academy Elementary School', 553),
#  (5.0, 'North Center', 6.0, 'John F Eberhart Elementary School', 1777),
#  (5.0, 'North Center', 6.0, 'John Fiske Elementary School', 254),
#  (5.0, 'North Center', 6.0, 'John F Kennedy High School', 1589),
#  (5.0, 'North Center', 6.0, 'John Foster Dulles Elementary School', 537),
#  (5.0, 'North Center', 6.0, 'John Greenleaf Whittier Elementary School', 409),
#  (5.0, 'North Center', 6.0, 'John Hancock College Preparatory High School', 967),
#  (5.0, 'North Center', 6.0, 'John Harvard Elementary School of Excellence', 476),
#  (5.0, 'North Center', 6.0, 'John Hay Elementary Community Academy', 554),
#  (5.0, 'North Center', 6.0, 'John H Hamline Elementary School', 679),
#  (5.0, 'North Center', 6.0, 'John H Kinzie Elementary School', 733),
#  (5.0, 'North Center', 6.0, 'John H Vanderpoel Elementary Magnet School', 317),
#  (5.0, 'North Center', 6.0, 'John J Audubon Elementary School', 580),
#  (5.0, 'North Center', 6.0, 'John J Pershing Elementary Humanities Magnet', 258),
#  (5.0, 'North Center', 6.0, 'John L Marsh Elementary School', 841),
#  (5.0, 'North Center', 6.0, 'John Marshall Metropolitan High School', 726),
#  (5.0, 'North Center', 6.0, 'John M Harlan Community Academy High School', 1245),
#  (5.0, 'North Center', 6.0, 'John Milton Gregory Elementary School', 323),
#  (5.0, 'North Center', 6.0, 'John M Smyth Elementary School', 475),
#  (5.0, 'North Center', 6.0, 'Johnnie Colemon Elementary Academy', 266),
#  (5.0, 'North Center', 6.0, 'John Palmer Elementary School', 919),
#  (5.0, 'North Center', 6.0, 'John P Altgeld Elementary School', 527),
#  (5.0, 'North Center', 6.0, 'John Spry Elementary Community School', 809),
#  (5.0, 'North Center', 6.0, 'John T McCutcheon Elementary School', 355),
#  (5.0, 'North Center', 6.0, 'John T Pirie Fine Arts & Academic Center Elementary School', 384),
#  (5.0, 'North Center', 6.0, 'John W Cook Elementary School', 482),
#  (5.0, 'North Center', 6.0, 'John W Garvy Elementary School', 720),
#  (5.0, 'North Center', 6.0, 'John Whistler Elementary School', 375),
#  (5.0, 'North Center', 6.0, 'Jonathan Burr Elementary School', 348),
#  (5.0, 'North Center', 6.0, 'Jonathan Y Scammon Elementary School', 937),
#  (5.0, 'North Center', 6.0, 'Jordan Elementary Community School', 753),
#  (5.0, 'North Center', 6.0, 'Jose De Diego Elementary Community Academy', 869),
#  (5.0, 'North Center', 6.0, 'Josefa Ortiz De Dominguez Elementary School', 793),
#  (5.0, 'North Center', 6.0, 'Joseph Brennemann Elementary School', 362),
#  (5.0, 'North Center', 6.0, 'Joseph E Gary Elementary School', 1204),
#  (5.0, 'North Center', 6.0, 'Josephine C Locke Elementary School', 1317),
#  (5.0, 'North Center', 6.0, 'Joseph Jungman Elementary School', 286),
#  (5.0, 'North Center', 6.0, 'Joseph Kellman Corporate Community Elementary School', 293),
#  (5.0, 'North Center', 6.0, 'Joseph Lovett Elementary School', 490),
#  (5.0, 'North Center', 6.0, 'Joseph Stockton Elementary School', 462),
#  (5.0, 'North Center', 6.0, 'Joseph Warren Elementary School', 328),
#  (5.0, 'North Center', 6.0, 'Joshua D Kershaw Elementary School', 262),
#  (5.0, 'North Center', 6.0, 'Josiah Pickard Elementary School', 656),
#  (5.0, 'North Center', 6.0, 'Joyce Kilmer Elementary School', 886),
#  (5.0, 'North Center', 6.0, 'Julia C Lathrop Elementary School', 83),
#  (5.0, 'North Center', 6.0, 'Julia Ward Howe Elementary School of Excellence', 576),
#  (5.0, 'North Center', 6.0, 'Kate S Buckingham Special Education Center', 26),
#  (5.0, 'North Center', 6.0, 'Kate S Kellogg Elementary School', 283),
#  (5.0, 'North Center', 6.0, 'Kelvyn Park High School', 1252),
#  (5.0, 'North Center', 6.0, 'Kenwood Academy High School', 1852),
#  (5.0, 'North Center', 6.0, 'Lake View High School', 1500),
#  (5.0, 'North Center', 6.0, 'Langston Hughes Elementary School', 424),
#  (5.0, 'North Center', 6.0, 'LaSalle Elementary Language Academy', 576),
#  (5.0, 'North Center', 6.0, 'LaSalle II Magnet Elementary School', 609),
#  (5.0, 'North Center', 6.0, 'Laughlin Falconer Elementary School', 1520),
#  (5.0, 'North Center', 6.0, 'Laura S Ward Elementary School', 429),
#  (5.0, 'North Center', 6.0, 'Lawndale Elementary Community Academy', 508),
#  (5.0, 'North Center', 6.0, 'Lazaro Cardenas Elementary School', 654),
#  (5.0, 'North Center', 6.0, 'Leif Ericson Elementary Scholastic Academy', 518),
#  (5.0, 'North Center', 6.0, 'Lenart Elementary Regional Gifted Center', 328),
#  (5.0, 'North Center', 6.0, 'Leslie Lewis Elementary School', 565),
#  (5.0, 'North Center', 6.0, 'Lincoln Park High School', 2342),
#  (5.0, 'North Center', 6.0, 'Lionel Hampton Fine & Performing Arts Elementary School', 658),
#  (5.0, 'North Center', 6.0, 'Little Village Elementary School', 842),
#  (5.0, 'North Center', 6.0, 'Logandale Middle School', 941),
#  (5.0, 'North Center', 6.0, 'Lorenz Brentano Math & Science Academy Elementary School', 455),
#  (5.0, 'North Center', 6.0, 'Louis A Agassiz Elementary School', 432),
#  (5.0, 'North Center', 6.0, 'Louisa May Alcott Elementary School', 481),
#  (5.0, 'North Center', 6.0, 'Louis Armstrong Math & Science Elementary School', 93),
#  (5.0, 'North Center', 6.0, 'Louis Nettelhorst Elementary School', 729),
#  (5.0, 'North Center', 6.0, 'Louis Pasteur Elementary School', 1173),
#  (5.0, 'North Center', 6.0, 'Ludwig Van Beethoven Elementary School', 411),
#  (5.0, 'North Center', 6.0, "Luke O'Toole Elementary School", 511),
#  (5.0, 'North Center', 6.0, 'Luther Burbank Elementary School', 1139),
#  (5.0, 'North Center', 6.0, 'Lyman A Budlong Elementary School', 864),
#  (5.0, 'North Center', 6.0, 'Lyman Trumbull Elementary School', 438),
#  (5.0, 'North Center', 6.0, 'Mahalia Jackson Elementary School', 323),
#  (5.0, 'North Center', 6.0, 'Mancel Talcott Elementary School', 580),
#  (5.0, 'North Center', 6.0, 'Manley Career Academy High School', 599),
#  (5.0, 'North Center', 6.0, 'Manuel Perez Elementary School', 426),
#  (5.0, 'North Center', 6.0, 'Marcus Moziah Garvey Elementary School', 356),
#  (5.0, 'North Center', 6.0, 'Mariano Azuela Elementary School', 873),
#  (5.0, 'North Center', 6.0, 'Maria Saucedo Elementary Scholastic Academy', 1306),
#  (5.0, 'North Center', 6.0, 'Marie Sklodowska Curie Metropolitan High School', 3320),
#  (5.0, 'North Center', 6.0, 'Marine Military Math and Science Academy', 366),
#  (5.0, 'North Center', 6.0, 'Mark Sheridan Elementary Math & Science Academy', 535),
#  (5.0, 'North Center', 6.0, 'Mark Skinner Elementary School', 784),
#  (5.0, 'North Center', 6.0, 'Mark Twain Elementary School', 1161),
#  (5.0, 'North Center', 6.0, 'Marquette Elementary School', 1390),
#  (5.0, 'North Center', 6.0, 'Martha Ruggles Elementary School', 417),
#  (5.0, 'North Center', 6.0, 'Martin A Ryerson Elementary School', 445),
#  (5.0, 'North Center', 6.0, 'Marvin Camras Elementary School', 826),
#  (5.0, 'North Center', 6.0, 'Mary E Courtenay Elementary Language Arts Center', 257),
#  (5.0, 'North Center', 6.0, 'Mary E McDowell Elementary School', 188),
#  (5.0, 'North Center', 6.0, 'Mary Gage Peterson Elementary School', 860),
#  (5.0, 'North Center', 6.0, 'Mary Lyon Elementary School', 1423),
#  (5.0, 'North Center', 6.0, 'Mary Mapes Dodge Elementary Renaissance Academy', 434),
#  (5.0, 'North Center', 6.0, 'Mary McLeod Bethune Elementary School', 362),
#  (5.0, 'North Center', 6.0, 'Mason High School', 48),
#  (5.0, 'North Center', 6.0, 'Matthew A Henson Elementary School', 271),
#  (5.0, 'North Center', 6.0, 'Matthew Gallistel Elementary Language Academy', 1408),
#  (5.0, 'North Center', 6.0, 'Medgar Evers Elementary School', 367),
#  (5.0, 'North Center', 6.0, 'Melville W Fuller Elementary School', 241),
#  (5.0, 'North Center', 6.0, 'Michael Faraday Elementary School', 194),
#  (5.0, 'North Center', 6.0, 'Michael M Byrne Elementary School', 705),
#  (5.0, 'North Center', 6.0, 'Michele Clark Academic Prep Magnet High School', 726),
#  (5.0, 'North Center', 6.0, 'Mildred I Lavizzo Elementary School', 394),
#  (5.0, 'North Center', 6.0, 'Milton Brunson Math & Science Specialty Elementary School', 658),
#  (5.0, 'North Center', 6.0, 'Minnie Mars Jamieson Elementary School', 811),
#  (5.0, 'North Center', 6.0, 'Miriam G Canter Middle School', 222),
#  (5.0, 'North Center', 6.0, 'Morgan Park High School', 1584),
#  (5.0, 'North Center', 6.0, 'Morton School of Excellence', 349),
#  (5.0, 'North Center', 6.0, 'Moses Montefiore Special Elementary School', 21),
#  (5.0, 'North Center', 6.0, 'Mount Greenwood Elementary School', 909),
#  (5.0, 'North Center', 6.0, 'Mount Vernon Elementary School', 290),
#  (5.0, 'North Center', 6.0, 'Multicultural Academy of Scholarship', 324),
#  (5.0, 'North Center', 6.0, 'Myra Bradwell Communications Arts & Sciences Elementary School', 775),
#  (5.0, 'North Center', 6.0, 'Nathanael Greene Elementary School', 631),
#  (5.0, 'North Center', 6.0, 'Nathan Hale Elementary School', 872),
#  (5.0, 'North Center', 6.0, 'Nathaniel Pope Elementary School', 200),
#  (5.0, 'North Center', 6.0, 'Nathan R Goldblatt Elementary School', 268),
#  (5.0, 'North Center', 6.0, 'Nathan S Davis Elementary School', 1032),
#  (5.0, 'North Center', 6.0, 'National Teachers Elementary Academy', 446),
#  (5.0, 'North Center', 6.0, 'Neal F Simeon Career Academy High School', 1535),
#  (5.0, 'North Center', 6.0, 'Near North Elementary School', 91),
#  (5.0, 'North Center', 6.0, 'New Field Elementary School', 696),
#  (5.0, 'North Center', 6.0, 'New Millennium High School of Health at Bowen', 701),
#  (5.0, 'North Center', 6.0, 'Newton Bateman Elementary School', 1015),
#  (5.0, 'North Center', 6.0, 'Nicholas Senn High School', 1053),
#  (5.0, 'North Center', 6.0, 'Nicholson Technology Academy', 464),
#  (5.0, 'North Center', 6.0, 'Ninos Heroes Elementary Academic Center', 435),
#  (5.0, 'North Center', 6.0, 'Norman A Bridge Elementary School', 1004),
#  (5.0, 'North Center', 6.0, 'North-Grand High School', 883),
#  (5.0, 'North Center', 6.0, 'North River Elementary School', 359),
#  (5.0, 'North Center', 6.0, 'Northside College Preparatory High School', 1053),
#  (5.0, 'North Center', 6.0, 'Percy L Julian High School', 1226),
#  (5.0, 'North Center', 6.0, 'Northside Learning Center High School', 298),
#  (5.0, 'North Center', 6.0, 'Northwest Middle School', 756),
#  (5.0, 'North Center', 6.0, 'Norwood Park Elementary School', 359),
#  (5.0, 'North Center', 6.0, 'Ogden International High School', 558),
#  (5.0, 'North Center', 6.0, 'Ole A Thorp Elementary Scholastic Academy', 834),
#  (5.0, 'North Center', 6.0, 'Oliver S Westcott Elementary School', 413),
#  (5.0, 'North Center', 6.0, 'Oliver Wendell Holmes Elementary School', 334),
#  (5.0, 'North Center', 6.0, 'Oriole Park Elementary School', 648),
#  (5.0, 'North Center', 6.0, 'Orozco Fine Arts & Sciences Elementary School', 636),
#  (5.0, 'North Center', 6.0, 'Orr Academy High School', 831),
#  (5.0, 'North Center', 6.0, 'Orville T Bright Elementary School', 361),
#  (5.0, 'North Center', 6.0, 'Oscar DePriest Elementary School', 524),
#  (5.0, 'North Center', 6.0, 'Oscar F Mayer Elementary School', 605),
#  (5.0, 'North Center', 6.0, 'Pablo Casals Elementary School', 505),
#  (5.0, 'North Center', 6.0, 'Park Manor Elementary School', 352),
#  (5.0, 'North Center', 6.0, 'Parkside Elementary Community Academy', 348),
#  (5.0, 'North Center', 6.0, 'Patrick Henry Elementary School', 650),
#  (5.0, 'North Center', 6.0, 'Paul Cuffe Math-Science Technology Academy Elementary School', 512),
#  (5.0, 'North Center', 6.0, 'Paul Laurence Dunbar Career Academy High School', 1456),
#  (5.0, 'North Center', 6.0, 'Paul Revere Elementary School', 320),
#  (5.0, 'North Center', 6.0, 'Paul Robeson High School', 733),
#  (5.0, 'North Center', 6.0, 'Perkins Bass Elementary School', 369),
#  (5.0, 'North Center', 6.0, 'Pershing West Middle School', 269),
#  (5.0, 'North Center', 6.0, 'Peter A Reinberg Elementary School', 832),
#  (5.0, 'North Center', 6.0, 'Peter Cooper Elementary Dual Language Academy', 709),
#  (5.0, 'North Center', 6.0, 'Philip Rogers Elementary School', 735),
#  (5.0, 'North Center', 6.0, 'Phillip D Armour Elementary School', 365),
#  (5.0, 'North Center', 6.0, 'Phillip Murray Elementary Language Academy', 533),
#  (5.0, 'North Center', 6.0, 'Phobe Apperson Hearst Elementary School', 364),
#  (5.0, 'North Center', 6.0, 'Phoenix Military Academy High School', 461),
#  (5.0, 'North Center', 6.0, 'Pilsen Elementary Community Academy', 447),
#  (5.0, 'North Center', 6.0, 'Portage Park Elementary School', 1139),
#  (5.0, 'North Center', 6.0, 'Pulaski International Academy Elmentary School', 864),
#  (5.0, 'North Center', 6.0, 'Rachel Carson Elementary School', 1222),
#  (5.0, 'North Center', 6.0, 'Ralph H Metcalfe Elementary Community Academy', 489),
#  (5.0, 'North Center', 6.0, 'Ravenswood Elementary School', 465),
#  (5.0, 'North Center', 6.0, 'Ray Graham Training Center High School', 137),
#  (5.0, 'North Center', 6.0, 'Richard Edwards Elementary School', 1503),
#  (5.0, 'North Center', 6.0, 'Richard Henry Lee Elementary School', 832),
#  (5.0, 'North Center', 6.0, 'Richard J Daley Elementary Academy', 797),
#  (5.0, 'North Center', 6.0, 'Richard J Oglesby Elementary School', 402),
#  (5.0, 'North Center', 6.0, 'Richard T Crane Technical Preparatory High School', 478),
#  (5.0, 'North Center', 6.0, 'Richard Yates Elementary School', 690),
#  (5.0, 'North Center', 6.0, 'Roald Amundsen High School', 1532),
#  (5.0, 'North Center', 6.0, 'Robert A Black Magnet Elementary School', 474),
#  (5.0, 'North Center', 6.0, 'Robert Emmet Elementary School', 460),
#  (5.0, 'North Center', 6.0, 'Robert Fulton Elementary School', 466),
#  (5.0, 'North Center', 6.0, 'Robert Healy Elementary School', 1384),
#  (5.0, 'North Center', 6.0, 'Robert H Lawrence Elementary School', 371),
#  (5.0, 'North Center', 6.0, 'Robert L Grimes Elementary School', 486),
#  (5.0, 'North Center', 6.0, 'Robert Lindblom Math & Science Academy High School', 916),
#  (5.0, 'North Center', 6.0, 'Robert Nathaniel Dett Elementary School', 250),
#  (5.0, 'North Center', 6.0, 'Roberto Clemente Community Academy High School', 1016),
#  (5.0, 'North Center', 6.0, 'Rodolfo Lozano Bilingual & International Center Elementary School', 319),
#  (5.0, 'North Center', 6.0, 'Roger C Sullivan High School', 826),
#  (5.0, 'North Center', 6.0, 'Ronald Brown Elementary Community Academy', 283),
#  (5.0, 'North Center', 6.0, 'Ronald E McNair Elementary School', 422),
#  (5.0, 'North Center', 6.0, 'Rosario Castellanos Elementary School', 525),
#  (5.0, 'North Center', 6.0, 'Roswell B Mason Elementary School', 479),
#  (5.0, 'North Center', 6.0, 'Rudyard Kipling Elementary School', 445),
#  (5.0, 'North Center', 6.0, 'Rueben Salazar Elementary Bilingual Center', 444),
#  (5.0, 'North Center', 6.0, 'Rufus M Hitch Elementary School', 542),
#  (5.0, 'North Center', 6.0, 'Salmon P Chase Elementary School', 504),
#  (5.0, 'North Center', 6.0, 'Samuel Gompers Fine Arts Options Elementary School', 285),
#  (5.0, 'North Center', 6.0, 'Sauganash Elementary School', 549),
#  (5.0, 'North Center', 6.0, 'Scott Joplin Elementary School', 538),
#  (5.0, 'North Center', 6.0, 'Sharon Christa McAuliffe Elementary School', 862),
#  (5.0, 'North Center', 6.0, 'Sidney Sawyer Elementary School', 1846),
#  (5.0, 'North Center', 6.0, 'Simon Guggenheim Elementary School', 291),
#  (5.0, 'North Center', 6.0, 'Sir Miles Davis Magnet Elementary Academy', 354),
#  (5.0, 'North Center', 6.0, 'Skinner North', 242),
#  (5.0, 'North Center', 6.0, 'Socorro Sandoval Elementary School', 1186),
#  (5.0, 'North Center', 6.0, 'Songhai Elementary Learning Institute', 352),
#  (5.0, 'North Center', 6.0, 'South Loop Elementary School', 795),
#  (5.0, 'North Center', 6.0, 'South Shore Fine Arts Academy', 255),
#  (5.0, 'North Center', 6.0, 'Southside Occupational Academy High School', 201),
#  (5.0, 'North Center', 6.0, 'Spencer Technology Academy', 811),
#  (5.0, 'North Center', 6.0, 'Spry Community Links High School', 205),
#  (5.0, 'North Center', 6.0, 'Stephen Decatur Classical Elementary School', 289),
#  (5.0, 'North Center', 6.0, 'Stephen F Gale Elementary Community Academy', 532),
#  (5.0, 'North Center', 6.0, 'Stephen K Hayt Elementary School', 1000),
#  (5.0, 'North Center', 6.0, 'Stephen T Mather High School', 1657),
#  (5.0, 'North Center', 6.0, 'Stone Elementary Scholastic Academy', 646),
#  (5.0, 'North Center', 6.0, 'Suder Montessori Magnet Elementary School', 351),
#  (5.0, 'North Center', 6.0, 'Talman Elementary School', 376),
#  (5.0, 'North Center', 6.0, 'Tarkington School of Excellence Elementary School', 1070),
#  (5.0, 'North Center', 6.0, 'TEAM Englewood Community Academy High School', 440),
#  (5.0, 'North Center', 6.0, 'Telpochcalli Elementary School', 285),
#  (5.0, 'North Center', 6.0, 'Theodore Herzl Elementary School', 512),
#  (5.0, 'North Center', 6.0, 'Theodore Roosevelt High School', 1490),
#  (5.0, 'North Center', 6.0, 'Theophilus Schmid Elementary School', 185),
#  (5.0, 'North Center', 6.0, 'Thomas A Edison Regional Gifted Center Elementary School', 269),
#  (5.0, 'North Center', 6.0, 'Thomas A Hendricks Elementary Community Academy', 307),
#  (5.0, 'North Center', 6.0, 'Thomas Chalmers Specialty Elementary School', 288),
#  (5.0, 'North Center', 6.0, 'Thomas Drummond Elementary School', 352),
#  (5.0, 'North Center', 6.0, 'Thomas Hoyne Elementary School', 288),
#  (5.0, 'North Center', 6.0, 'Thomas J Higgins Elementary Community Academy', 369),
#  (5.0, 'North Center', 6.0, 'Thomas J Waters Elementary School', 590),
#  (5.0, 'North Center', 6.0, 'Thomas Kelly High School', 2883),
#  (5.0, 'North Center', 6.0, 'Thurgood Marshall Middle School', 435),
#  (5.0, 'North Center', 6.0, 'Turner-Drew Elementary Language Academy', 373),
#  (5.0, 'North Center', 6.0, 'Uplift Community High School', 473),
#  (5.0, 'North Center', 6.0, 'Velma F Thomas Early Childhood Center', 211),
#  (5.0, 'North Center', 6.0, 'Victor Herbert Elementary School', 398),
#  (5.0, 'North Center', 6.0, 'Virgil Grissom Elementary School', 330),
#  (5.0, 'North Center', 6.0, 'VOISE Academy High School', 410),
#  (5.0, 'North Center', 6.0, 'Walt Disney Magnet Elementary School', 1651),
#  (5.0, 'North Center', 6.0, 'Walter L Newberry Math & Science Academy Elementary School', 558),
#  (5.0, 'North Center', 6.0, 'Walter Payton College Preparatory High School', 881),
#  (5.0, 'North Center', 6.0, 'Walter Q Gresham Elementary School', 359),
#  (5.0, 'North Center', 6.0, 'Walter Reed Elementary School', 44),
#  (5.0, 'North Center', 6.0, 'Walter S Christopher Elementary School', 279),
#  (5.0, 'North Center', 6.0, 'Washington D Smyser Elementary School', 1047),
#  (5.0, 'North Center', 6.0, 'Washington Irving Elementary School', 482),
#  (5.0, 'North Center', 6.0, 'Wells Community Academy High School', 633),
#  (5.0, 'North Center', 6.0, 'Wendell E Green Elementary School', 254),
#  (5.0, 'North Center', 6.0, 'Wendell Phillips Academy High School', 590),
#  (5.0, 'North Center', 6.0, 'Wendell Smith Elementary School', 363),
#  (5.0, 'North Center', 6.0, 'West Park Elementary Academy', 686),
#  (5.0, 'North Center', 6.0, 'West Pullman Elementary School', 343),
#  (5.0, 'North Center', 6.0, 'West Ridge Elementary School', 659),
#  (5.0, 'North Center', 6.0, 'Whitney M Young Magnet High School', 2166),
#  (5.0, 'North Center', 6.0, 'Wildwood Elementary School', 414),
#  (5.0, 'North Center', 6.0, 'Willa Cather Elementary School', 234),
#  (5.0, 'North Center', 6.0, 'William A Hinton Elementary School', 321),
#  (5.0, 'North Center', 6.0, 'William Bishop Owen Scholastic Academy Elementary School', 243),
#  (5.0, 'North Center', 6.0, 'William B Ogden Elementary School', 722),
#  (5.0, 'North Center', 6.0, 'William C Goudy Elementary School', 805),
#  (5.0, 'North Center', 6.0, 'William C Reavis Math & Science Specialty Elementary School', 311),
#  (5.0, 'North Center', 6.0, 'William E B Dubois Elementary School', 184),
#  (5.0, 'North Center', 6.0, 'William E Dever Elementary School', 843),
#  (5.0, 'North Center', 6.0, 'William F Finkl Elementary School', 588),
#  (5.0, 'North Center', 6.0, 'William G Hibbard Elementary School', 1239),
#  (5.0, 'North Center', 6.0, 'William H Brown Elementary School', 217),
#  (5.0, 'North Center', 6.0, 'William H King Elementary School', 264),
#  (5.0, 'North Center', 6.0, 'William Howard Taft High School', 2922),
#  (5.0, 'North Center', 6.0, 'William H Prescott Elementary School', 240),
#  (5.0, 'North Center', 6.0, 'William H Ray Elementary School', 654),
#  (5.0, 'North Center', 6.0, 'William H Ryder Math & Science Specialty Elementary School', 302),
#  (5.0, 'North Center', 6.0, 'William H Seward Communication Arts Academy Elementary School', 896),
#  (5.0, 'North Center', 6.0, 'William J Bogan High School', 1656),
#  (5.0, 'North Center', 6.0, 'William J & Charles H Mayo Elementary School', 453),
#  (5.0, 'North Center', 6.0, 'William J Onahan Elementary School', 687),
#  (5.0, 'North Center', 6.0, 'William Jones College Preparatory High School', 871),
#  (5.0, 'North Center', 6.0, 'William K New Sullivan Elementary School', 527),
#  (5.0, 'North Center', 6.0, 'William Penn Elementary School', 423),
#  (5.0, 'North Center', 6.0, 'William P Gray Elementary School', 1345),
#  (5.0, 'North Center', 6.0, 'William P Nixon Elementary School', 1061),
#  (5.0, 'North Center', 6.0, 'William Rainey Harper High School', 621),
#  (5.0, 'North Center', 6.0, 'Williams Multiplex Elementary School', 266),
#  (5.0, 'North Center', 6.0, 'Williams Preparatory Academy Middle School', 125),
#  (5.0, 'North Center', 6.0, 'William T Sherman Elementary School', 462),
#  (5.0, 'North Center', 6.0, 'William W Carter Elementary School', 371),
#  (5.0, 'North Center', 6.0, 'Wolfgang A Mozart Elementary School', 748),
#  (5.0, 'North Center', 6.0, 'Woodlawn Community Elementary School', 238),
#  (5.0, 'North Center', 6.0, 'World Language Academy High School', 382)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist. If the CHICAGO_SOCIOECONOMIC_DATA table does not exists, please execute the following code beforehand.
#
# df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv")
# df.to_sql("CENSUS_DATA", con, if_exists='replace', index=False,method="multi")
#
# %sql select community_area_number, community_area_name, hardship_index from CENSUS_DATA \
#    where community_area_number in \
#    ( select community_area_number from CHICAGO_PUBLIC_SCHOOLS_DATA order by college_enrollment desc limit 1 )
# -->

# %% [markdown]
# ## Summary
#
# ##### In this lab you learned how to work with a real word dataset using SQL and Python. You learned how to query columns with spaces or special characters in their names and with mixed case names. You also used built in database functions and practiced how to sort, limit, and order result sets, as well as used sub-queries and worked with multiple tables.

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Rav Ahuja</a>
# <!--
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                        |
# | ----------------- | ------- | ----------------- | ----------------------------------------- |
# | 2022-03-04        | 2.2     | Lakshmi Holla     | Made changes in markdown cells |
# | 2020-11-27        | 2.1     | Sannareddy Ramesh | Modified data sets and added new problems |
# | 2020-08-28        | 2.0     | Lavanya           | Moved lab to course repo in GitLab        |
# -->
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
